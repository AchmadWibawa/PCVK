# %% [markdown]
# <a href="https://colab.research.google.com/github/AchmadWibawa/PCVK/blob/master/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Step 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display 
from skimage import io
from skimage import transform 
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ## Step 2

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg"
        ,"https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg"
        ,"https://placekitten.com/800/571"]

for url in urls:
  image = io.imread(url)
  #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor (image, cv.COLOR_BGR2RGB) #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7FEABBE8BA00>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FEABBE8B880>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FEABB709CA0>

# %% [markdown]
# ## Step 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi, " x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7FEAFC722280>

# %% [markdown]
# ## langkah 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255, 255, 255]

final_frame = cv.hconcat ((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FEAFC7221F0>

# %% [markdown]
# ## Jawaban Pertanyaan
#
# 1. karena dengan menggunakan google collab kita dapat menyimpan file di github dengan mudah serta kita tidak perlu menginstall python di laptop
#
# 2. library numpy menerapkan fungsi numerik
# library pandas digunakan untuk memanipulasi data
# library CV digunakan untuk memfasilitasi pemrograman citra digital
# library matplotlib digunakan untuk melakukan visualisasi data secara 2D maupun 3D
#
# 3. kode program tersebut digunakan untuk merisize gambar menjadi setengah ukuran aslinya agar ukuran gambar tidak terlalu besar
#
# 4. kegunaan kode program tersebut adalah untuk menentukan warna putih
#
# 5. semakin tinggi resolusi gambar, semakin bagus kualitasnya serta semakin banyak pula pixelnya. semakin rendah resolusi gambar semakin rendah kualitas gambar serta semakin sedikit pula pixelnya

# %% [markdown]
# ## Tugas

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal ditengah image
for y in range (tinggi):
  image_4[y,int((lebar)/2)] = [255, 255, 255]

#membuat garis menyilang diagonal didalam image
for y in range (tinggi):
  image_5[y,int(y*(lebar/tinggi))] = [255,255,255]
  image_5[y, lebar-1-int(y*(lebar/tinggi))] = [255,255,255]
  
final_frame = cv.hconcat ((image_2, image_4, image_5))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x286 at 0x7FEABB63E130>

# %%
# membuat garis dengan panjang tertentu
image_6 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
for y in range (0,110):
  image_6[int((lebar)/3),80+y] = [255, 255, 255]

final_frame = cv.hconcat ((image_2, image_6))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FEABBE8B5E0>

# %%
image_7 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (100, 210):  
  for y in range(100, 210): 
    image_7[x, y] = [255,255,255]


final_frame = cv.hconcat((image_2, image_7))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FEAFC713E20>
