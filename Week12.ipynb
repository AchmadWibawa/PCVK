# %% [markdown]
# <a href="https://colab.research.google.com/github/AchmadWibawa/PCVK/blob/master/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Achmad Wibawa / 01 / 2041720174

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## Lakukan Face Detection untuk image object lain yang tersedia pada (/images/facedet). Tampilkan seperti pada contoh berikut. Perhatikan pada hasil face detection dibawah ini. Secara keseluruhan, face detection dapat dilakukan dengan baik, bahkan untuk image berupa gambar bukan foto, wajah bermasker, atau wajah yang berukuran kecil (solvay).

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_frontalface_alt.xml')

jokowi_asl = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/jokowi.jpg')
jokowi = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/jokowi.jpg')

gray = cv.cvtColor(jokowi, cv.COLOR_BGR2GRAY)

roi_wajah = cascade_wajah.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

for (x, y, w, h) in roi_wajah:
    cv.rectangle(jokowi, (x, y), (x+w, y+h), (0, 255, 0), 3)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(jokowi_asl, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(jokowi_asl, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(jokowi, cv.COLOR_BGR2RGB))
plt.show()

# %%
kartini_asl = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/kartini.jpg')
kartini = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/kartini.jpg')

gray2 = cv.cvtColor(kartini, cv.COLOR_BGR2GRAY)

kar_wajah = cascade_wajah.detectMultiScale(gray2, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

for (x, y, w, h) in kar_wajah:
    cv.rectangle(kartini, (x, y), (x+w, y+h), (0, 255, 0), 3)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(kartini_asl, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(kartini_asl, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(kartini, cv.COLOR_BGR2RGB))
plt.show()

# %%
kucing_asl = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/kucing.jpg', 0)
kucing = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/kucing.jpg',0)

kuc_wajah = cascade_wajah.detectMultiScale(kucing, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

for (x, y, w, h) in kuc_wajah:
    cv.rectangle(kucing, (x, y), (x+w, y+h), (0, 255, 0), 3)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(kucing_asl, cmap='gray')
plt.subplot(122),plt.imshow(kucing, cmap='gray')
plt.show()

# %%
mask_asl = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mask.png', 0)
mask = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mask.png',0)

mask_wajah = cascade_wajah.detectMultiScale(mask, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

for (x, y, w, h) in mask_wajah:
    cv.rectangle(mask, (x, y), (x+w, y+h), (0, 255, 0), 3)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(mask_asl, cmap='gray')
plt.subplot(122),plt.imshow(mask, cmap='gray')
plt.show()

# %%
jordan_asl = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mjordan.jpg', 0)
jordan = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mjordan.jpg',0)

jordan_wajah = cascade_wajah.detectMultiScale(jordan, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

for (x, y, w, h) in jordan_wajah:
    cv.rectangle(jordan, (x, y), (x+w, y+h), (0, 255, 0), 3)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(jordan_asl, cmap='gray')
plt.subplot(122),plt.imshow(jordan, cmap='gray')
plt.show()

# %%
sol_asl = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/solvayconf.jpg', 0)
sol = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/solvayconf.jpg',0)

sol_wajah = cascade_wajah.detectMultiScale(sol, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

for (x, y, w, h) in sol_wajah:
    cv.rectangle(sol, (x, y), (x+w, y+h), (0, 255, 0), 3)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(sol_asl, cmap='gray')
plt.subplot(122),plt.imshow(sol, cmap='gray')
plt.show()

# %% [markdown]
# ## Pada Soal No.2. wajah kucing tidak bisa dideteksi dengan baik. Lakukan deteksi wajah kucing hingga muncul rectangle pada bagian wajahnya seperti gambar berikut. Petunjuk pada soal ini, perhatikan pretrained features yang telah disediakan OpenCV. Gunakan xml yang ada jika memang telah disediakan. Jika belum ada, coba cari dengan searching melalui search engines.

# %%
cascade_wajah2 = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_frontalcatface.xml')

kucing_asl2 = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/kucing.jpg', 0)
kucing2 = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/kucing.jpg',0)

kar_wajah2 = cascade_wajah2.detectMultiScale(kucing2)

for (x, y, w, h) in kar_wajah2:
    cv.rectangle(kucing2, (x, y), (x+w, y+h), (0, 255, 0), 3)
    break

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(kucing_asl2, cmap='gray')
plt.subplot(122),plt.imshow(kucing2, cmap='gray')
plt.show()

# %% [markdown]
# ## Cobakan juga untuk eyes detection pada gambar “Jokowi.jpg”.

# %%
cascade_mata = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_eye.xml')

jokowi_asl2 = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/jokowi.jpg',0)
jokowi2 = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/jokowi.jpg',0)

jok_wajah2 = cascade_mata.detectMultiScale(jokowi2)

for (x, y, w, h) in jok_wajah2:
    cv.rectangle(jokowi2, (x, y), (x+w, y+h), (255, 255, 255), 3)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(jokowi_asl2, cmap='gray')
plt.subplot(122),plt.imshow(jokowi2, cmap='gray')
plt.show()

# %% [markdown]
# ## Lakukan Face Tracking menggunakan Google Colab. Petunjuk, Tutorial selengkapnya tentang akses kamera dan FaceDetection pada google colab dapat dilihat di link berikut:
# https://www.youtube.com/watch?v=YiWh7QvVH60

# %% [markdown]
# ## Lakukan deteksi bagian wajah gambar “mjordan.jpg”, kemudian tindih bagian wajah tersebut dengan gambar “smile.png”.

# %%
jordan2 = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mjordan.jpg')
emoji = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/smile.png', cv.IMREAD_UNCHANGED)

gray3 = cv.cvtColor(jordan2, cv.COLOR_BGR2GRAY)

jordan2_wajah = cascade_wajah.detectMultiScale(gray3, scaleFactor=1.1, minNeighbors=5)

for (x, y, w, h) in jordan2_wajah:
    emoji_resized = cv.resize(emoji, (w, h))
    overlay = cv.addWeighted(jordan2[y:y+h, x:x+w], 1, emoji_resized[:, :, 0:3], 1, 0)
    jordan2[y:y+h, x:x+w] = overlay

plt.figure(figsize=(12, 6))
plt.imshow(cv.cvtColor(jordan2, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ## Lakukan deteksi wajah dengan menggunakan bounding box berwarna hitam, deteksi mata menggunakan bounding box berwarna putih, dan deteksi mata kanan menggunakan bounding box berwarna merah. Gunakan gambar “people.jpg” untuk mengerjakan soal pada nomor ini.

# %%
face_cascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_frontalface_alt.xml')
eye_cascade = cv.CascadeClassifier('/content/drive/MyDrive/PCVK/Images/haarcascades/haarcascade_eye.xml')

img = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/people.jpg')

img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(img_gray, scaleFactor=1.1, minNeighbors=5)

for (x, y, w, h) in faces:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 0, 0), 1)
    roi_gray = img_gray[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray, scaleFactor=1.1, minNeighbors=5)
    for (ex, ey, ew, eh) in eyes:
        cv.rectangle(img, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 0, 255), 1)
        if ex + ew/2 > w/2:
            cv.rectangle(img, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (255, 255, 255), 1)

plt.figure(figsize=(12, 6))
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Result')
plt.axis('off')
plt.show()
