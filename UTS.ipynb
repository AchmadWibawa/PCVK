# %% [markdown]
# <a href="https://colab.research.google.com/github/AchmadWibawa/PCVK/blob/master/UTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Achmad Wibawa / 01 / 2041720174 / TI 3B

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import math
from google.colab.patches import cv2_imshow
from PIL import Image as im

# %% [markdown]
# ## Median Filter

# %%
def median_filter(data, filter_size):
    temp = []
    indexer = filter_size // 2
    data_final = []
    data_final = np.zeros((len(data),len(data[0])))
    for i in range(len(data)):

        for j in range(len(data[0])):

            for z in range(filter_size):
                if i + z - indexer < 0 or i + z - indexer > len(data) - 1:
                    for c in range(filter_size):
                        temp.append(0)
                else:
                    if j + z - indexer < 0 or j + indexer > len(data[0]) - 1:
                        temp.append(0)
                    else:
                        for k in range(filter_size):
                            temp.append(data[i + z - indexer][j + k - indexer])

            temp.sort()
            data_final[i][j] = temp[len(temp) // 2]
            temp = []
    return data_final

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/Images/noises/1.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
img_1 = median_filter(img_gray, 3)

arr = np.array(img_gray)
removed_noise = median_filter(arr, 3) 
img_filter = im.fromarray(removed_noise)

img_filter.show()
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=310x256 at 0x7F41D46F1040>
# <PIL.Image.Image image mode=L size=310x256 at 0x7F41D46F1280>
